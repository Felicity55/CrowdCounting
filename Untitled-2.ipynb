# %%
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
from numpy import ndarray
import torchvision.transforms as T
transform = T.Resize(size=(250,350))
# img=Image.open(r"D:\Soumi\License plate detection\1\1\Cars11.png").convert('RGB')
x=r"D:\Soumi\License plate detection\1\1\Cars11_hm.npy"
data= np.load(x)
# data=Image.fromarray(data)
# data=ndarray.reshape(data,(256,256))
data=transform(data)
# data=data.resize((int(256),int(256)))
# data=np.asarray(data)/256
print(data.shape)
# img.save(r"C:\Users\CVPR\Desktop/img11.png")

# plt.imshow(img)
plt.imshow(data, alpha=0.7)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-2.ipynb Cell 1 in <cell line: 12>()
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=8'>9</a> data= np.load(x)
#      <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=9'>10</a> # data=Image.fromarray(data)
#      <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=10'>11</a> # data=ndarray.reshape(data,(256,256))
# ---> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=11'>12</a> data=transform(data)
#      <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=12'>13</a> # data=data.resize((int(256),int(256)))
# ...

# %%
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
from numpy import ndarray
import torchvision.transforms as T
transform = T.Resize(size=(1000,1000))
img=Image.open(r"E:\Dataset\ISI-AMLPR\youtube\trainset\img_0.JPG").convert('RGB')
x=r"E:\Dataset\ISI-AMLPR\youtube\trainset\img_0_hm.npy"
data= np.load(x)
img=img.resize((1000,1000))
# print(img.size)
# np_img = np.asarray(img)
# print(np_img.shape)
# np_img=transform(np_img)

data=Image.fromarray(data)
# data=ndarray.reshape(data,(256,256))
data=transform(data)
# data=data.resize((1000,1000))
data=np.asarray(data)
# print(data.shape)
# # img.save(r"C:\Users\CVPR\Desktop/img11.png")

plt.imshow(img)
plt.imshow(data, alpha=0.7)
plt.show()
